# %%
import pandas as pd
import lzma
import math
import os

# %%
datasets = [name for name in os.listdir('training_data') if os.path.isdir(os.path.join('training_data', name))]

# %%
for dataset in datasets:
    for compress_type in ['mean', 'median']:
        for compress_size in [100, 1000, 2000]:
            print(f'{dataset:25} {compress_type} {compress_size}', end='\t')
            
            # Load count data with 'sequenceID' and 'count'
            length_df = pd.read_csv(f"training_data/{dataset}/features.csv")[['sequenceID', 'count']]

            # Load sequence data from CSV
            file_path = f'sequence_data/{dataset}/{compress_type}/{compress_size}/profiles.csv.xz'
            with lzma.open(file_path, 'rt') as file:
                signal_df = pd.read_csv(file)

            # Group sequences by 'sequenceID' and convert to dictionary for fast lookups
            seqs = {sequenceID: data for sequenceID, data in signal_df.groupby('sequenceID')}

            match_count = 0
            mismatch_count = 0

            # Iterate over 'sequenceID' in length_df and compare with sequences in seqs
            for i, row in length_df.iterrows():
                sequenceID = row['sequenceID']

                if sequenceID in seqs:
                    if row['count'] < compress_size:
                        ceil_value = row['count']  # Use actual count if it's less than compress_size
                    else:
                        ceil_value = math.ceil(row['count'] / compress_size)

                    seq_length = len(seqs[sequenceID])

                    if ceil_value == seq_length:
                        match_count += 1
                    else:
                        mismatch_count += 1
                        # Uncomment the following line for debugging
                        # print(f"No match for sequenceID {sequenceID}: {row['count']} vs {seq_length}")
                # else:
                #     mismatch_count += 1
                #     # Uncomment the following line for debugging
                #     # print(f"sequenceID {sequenceID} not found in signal data")

            print(f"Number of matches: {match_count:5} \t Number of mismatches: {mismatch_count}")
# Out:
# ATAC_JV_adipose           mean 100	Number of matches:   465 	 Number of mismatches: 0
# ATAC_JV_adipose           mean 1000	Number of matches:   465 	 Number of mismatches: 0
# ATAC_JV_adipose           mean 2000	Number of matches:   465 	 Number of mismatches: 0
# ATAC_JV_adipose           median 100	Number of matches:   465 	 Number of mismatches: 0
# ATAC_JV_adipose           median 1000	Number of matches:   465 	 Number of mismatches: 0
# ATAC_JV_adipose           median 2000	Number of matches:   465 	 Number of mismatches: 0
# CTCF_TDH_ENCODE           mean 100	Number of matches:   182 	 Number of mismatches: 0
# CTCF_TDH_ENCODE           mean 1000	Number of matches:   182 	 Number of mismatches: 0
# CTCF_TDH_ENCODE           mean 2000	Number of matches:   182 	 Number of mismatches: 0
# CTCF_TDH_ENCODE           median 100	Number of matches:   182 	 Number of mismatches: 0
# CTCF_TDH_ENCODE           median 1000	Number of matches:   182 	 Number of mismatches: 0
# CTCF_TDH_ENCODE           median 2000	Number of matches:   182 	 Number of mismatches: 0
# H3K27ac-H3K4me3_TDHAM_BP  mean 100	Number of matches:  2007 	 Number of mismatches: 0
# H3K27ac-H3K4me3_TDHAM_BP  mean 1000	Number of matches:  2008 	 Number of mismatches: 0
# H3K27ac-H3K4me3_TDHAM_BP  mean 2000	Number of matches:  2008 	 Number of mismatches: 0
# H3K27ac-H3K4me3_TDHAM_BP  median 100	Number of matches:  2008 	 Number of mismatches: 0
# H3K27ac-H3K4me3_TDHAM_BP  median 1000	Number of matches:  2003 	 Number of mismatches: 5
# H3K27ac-H3K4me3_TDHAM_BP  median 2000	Number of matches:  2008 	 Number of mismatches: 0
# H3K27ac_TDH_some          mean 100	Number of matches:    93 	 Number of mismatches: 2
# H3K27ac_TDH_some          mean 1000	Number of matches:    95 	 Number of mismatches: 0
# H3K27ac_TDH_some          mean 2000	Number of matches:    95 	 Number of mismatches: 0
# H3K27ac_TDH_some          median 100	Number of matches:    95 	 Number of mismatches: 0
# H3K27ac_TDH_some          median 1000	Number of matches:    93 	 Number of mismatches: 1
# H3K27ac_TDH_some          median 2000	Number of matches:    95 	 Number of mismatches: 0
# H3K27me3_RL_cancer        mean 100	Number of matches:   171 	 Number of mismatches: 0
# H3K27me3_RL_cancer        mean 1000	Number of matches:   171 	 Number of mismatches: 0
# H3K27me3_RL_cancer        mean 2000	Number of matches:   171 	 Number of mismatches: 0
# H3K27me3_RL_cancer        median 100	Number of matches:   171 	 Number of mismatches: 0
# H3K27me3_RL_cancer        median 1000	Number of matches:   171 	 Number of mismatches: 0
# H3K27me3_RL_cancer        median 2000	Number of matches:   171 	 Number of mismatches: 0
# H3K27me3_TDH_some         mean 100	Number of matches:    43 	 Number of mismatches: 0
# H3K27me3_TDH_some         mean 1000	Number of matches:    43 	 Number of mismatches: 0
# H3K27me3_TDH_some         mean 2000	Number of matches:    43 	 Number of mismatches: 0
# H3K27me3_TDH_some         median 100	Number of matches:    43 	 Number of mismatches: 0
# H3K27me3_TDH_some         median 1000	Number of matches:    42 	 Number of mismatches: 0
# H3K27me3_TDH_some         median 2000	Number of matches:    43 	 Number of mismatches: 0
# H3K36me3_AM_immune        mean 100	Number of matches:   412 	 Number of mismatches: 8
# H3K36me3_AM_immune        mean 1000	Number of matches:   420 	 Number of mismatches: 0
# H3K36me3_AM_immune        mean 2000	Number of matches:   420 	 Number of mismatches: 0
# H3K36me3_AM_immune        median 100	Number of matches:   420 	 Number of mismatches: 0
# H3K36me3_AM_immune        median 1000	Number of matches:   408 	 Number of mismatches: 10
# H3K36me3_AM_immune        median 2000	Number of matches:   420 	 Number of mismatches: 0
# H3K36me3_TDH_ENCODE       mean 100	Number of matches:    78 	 Number of mismatches: 0
# H3K36me3_TDH_ENCODE       mean 1000	Number of matches:    78 	 Number of mismatches: 0
# H3K36me3_TDH_ENCODE       mean 2000	Number of matches:    78 	 Number of mismatches: 0
# H3K36me3_TDH_ENCODE       median 100	Number of matches:    78 	 Number of mismatches: 0
# H3K36me3_TDH_ENCODE       median 1000	Number of matches:    78 	 Number of mismatches: 0
# H3K36me3_TDH_ENCODE       median 2000	Number of matches:    78 	 Number of mismatches: 0
# H3K36me3_TDH_immune       mean 100	Number of matches:    37 	 Number of mismatches: 0
# H3K36me3_TDH_immune       mean 1000	Number of matches:    37 	 Number of mismatches: 0
# H3K36me3_TDH_immune       mean 2000	Number of matches:    37 	 Number of mismatches: 0
# H3K36me3_TDH_immune       median 100	Number of matches:    37 	 Number of mismatches: 0
# H3K36me3_TDH_immune       median 1000	Number of matches:    36 	 Number of mismatches: 1
# H3K36me3_TDH_immune       median 2000	Number of matches:    37 	 Number of mismatches: 0
# H3K36me3_TDH_other        mean 100	Number of matches:    39 	 Number of mismatches: 0
# H3K36me3_TDH_other        mean 1000	Number of matches:    40 	 Number of mismatches: 0
# H3K36me3_TDH_other        mean 2000	Number of matches:    40 	 Number of mismatches: 0
# H3K36me3_TDH_other        median 100	Number of matches:    40 	 Number of mismatches: 0
# H3K36me3_TDH_other        median 1000	Number of matches:    38 	 Number of mismatches: 1
# H3K36me3_TDH_other        median 2000	Number of matches:    40 	 Number of mismatches: 0
# H3K4me1_TDH_BP            mean 100	Number of matches:   140 	 Number of mismatches: 3
# H3K4me1_TDH_BP            mean 1000	Number of matches:   144 	 Number of mismatches: 0
# H3K4me1_TDH_BP            mean 2000	Number of matches:   144 	 Number of mismatches: 0
# H3K4me1_TDH_BP            median 100	Number of matches:   144 	 Number of mismatches: 0
# H3K4me1_TDH_BP            median 1000	Number of matches:   136 	 Number of mismatches: 7
# H3K4me1_TDH_BP            median 2000	Number of matches:   144 	 Number of mismatches: 0
# H3K4me3_PGP_immune        mean 100	Number of matches:   293 	 Number of mismatches: 4
# H3K4me3_PGP_immune        mean 1000	Number of matches:   297 	 Number of mismatches: 0
# H3K4me3_PGP_immune        mean 2000	Number of matches:   297 	 Number of mismatches: 0
# H3K4me3_PGP_immune        median 100	Number of matches:   297 	 Number of mismatches: 0
# H3K4me3_PGP_immune        median 1000	Number of matches:   297 	 Number of mismatches: 0
# H3K4me3_PGP_immune        median 2000	Number of matches:   297 	 Number of mismatches: 0
# H3K4me3_TDH_ENCODE        mean 100	Number of matches:    74 	 Number of mismatches: 1
# H3K4me3_TDH_ENCODE        mean 1000	Number of matches:    75 	 Number of mismatches: 0
# H3K4me3_TDH_ENCODE        mean 2000	Number of matches:    75 	 Number of mismatches: 0
# H3K4me3_TDH_ENCODE        median 100	Number of matches:    75 	 Number of mismatches: 0
# H3K4me3_TDH_ENCODE        median 1000	Number of matches:    75 	 Number of mismatches: 0
# H3K4me3_TDH_ENCODE        median 2000	Number of matches:    75 	 Number of mismatches: 0
# H3K4me3_TDH_immune        mean 100	Number of matches:   377 	 Number of mismatches: 0
# H3K4me3_TDH_immune        mean 1000	Number of matches:   378 	 Number of mismatches: 0
# H3K4me3_TDH_immune        mean 2000	Number of matches:   378 	 Number of mismatches: 0
# H3K4me3_TDH_immune        median 100	Number of matches:   378 	 Number of mismatches: 0
# H3K4me3_TDH_immune        median 1000	Number of matches:   378 	 Number of mismatches: 0
# H3K4me3_TDH_immune        median 2000	Number of matches:   378 	 Number of mismatches: 0
# H3K4me3_TDH_other         mean 100	Number of matches:    90 	 Number of mismatches: 0
# H3K4me3_TDH_other         mean 1000	Number of matches:    90 	 Number of mismatches: 0
# H3K4me3_TDH_other         mean 2000	Number of matches:    90 	 Number of mismatches: 0
# H3K4me3_TDH_other         median 100	Number of matches:    90 	 Number of mismatches: 0
# H3K4me3_TDH_other         median 1000	Number of matches:    90 	 Number of mismatches: 0
# H3K4me3_TDH_other         median 2000	Number of matches:    90 	 Number of mismatches: 0
# H3K4me3_XJ_immune         mean 100	Number of matches:   268 	 Number of mismatches: 1
# H3K4me3_XJ_immune         mean 1000	Number of matches:   270 	 Number of mismatches: 0
# H3K4me3_XJ_immune         mean 2000	Number of matches:   270 	 Number of mismatches: 0
# H3K4me3_XJ_immune         median 100	Number of matches:   270 	 Number of mismatches: 0
# H3K4me3_XJ_immune         median 1000	Number of matches:   270 	 Number of mismatches: 0
# H3K4me3_XJ_immune         median 2000	Number of matches:   270 	 Number of mismatches: 0
# H3K9me3_TDH_BP            mean 100	Number of matches:   119 	 Number of mismatches: 0
# H3K9me3_TDH_BP            mean 1000	Number of matches:   120 	 Number of mismatches: 0
# H3K9me3_TDH_BP            mean 2000	Number of matches:   120 	 Number of mismatches: 0
# H3K9me3_TDH_BP            median 100	Number of matches:   120 	 Number of mismatches: 0
# H3K9me3_TDH_BP            median 1000	Number of matches:   119 	 Number of mismatches: 1
# H3K9me3_TDH_BP            median 2000	Number of matches:   120 	 Number of mismatches: 0
